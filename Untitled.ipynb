# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pylab
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
pylab.rcParams['figure.figsize'] = (15, 9)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data = pd.read_csv("customer.csv")
data
# Out:
#       Current Period  Customer ID  Periods Active Current Customer (Y/N)  \
# 0                  3         1434               1                      N
# 1                  3         1435               4                      N
# 2                  3         1436               2                      N
# 3                  3         1437               3                      N
# 4                  3         1438               2                      N
# 5                  3         1439               1                      N
# 6                  3         1440               1                      N
# 7                  3         1441               1                      N
# 8                  3         1442               1                      N
# 9                  3         1443               2                      N
# 10                 3         1444               1                      N
# 11                 3         1445               1                      N
# ...

# %%
_ = plt.hist(data[data["Current Customer (Y/N)"] == "Y"]["Revenue, Total"], bins=20)

# %%
data['Co. Age'].value_counts().plot(kind='bar')

# %%
data[data["Current Customer (Y/N)"] == "Y"][data["Acquisition Channel"] == "Internal"]["Revenue, Total"].describe()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# count       245.000000
# mean      42391.836735
# std       44552.896526
# min           0.000000
# 25%           0.000000
# 50%       29000.000000
# 75%       58000.000000
# max      245000.000000
# Name: Revenue, Total, dtype: float64

# %%
data[data["Current Customer (Y/N)"] == "Y"][data["Acquisition Channel"] == "External"]["Revenue, Total"].describe()
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# count       204.000000
# mean      42181.372549
# std       42766.998995
# min           0.000000
# 25%           0.000000
# 50%       29000.000000
# 75%       65000.000000
# max      221000.000000
# Name: Revenue, Total, dtype: float64

# %%
data.groupby("Periods Active").mean()
# Out:
#                 Current Period  Customer ID  Period Acquired  \
# Periods Active
# 1                          3.0  2057.773927        -0.051155
# 2                          3.0  1954.474308        -0.521739
# 3                          3.0  1820.483051        -1.415254
# 4                          3.0  1768.915254        -1.779661
# 5                          3.0  1676.344828        -2.413793
# 6                          3.0  1599.818182        -3.272727
# 7                          3.0  1562.571429        -4.000000
# 8                          3.0  1448.000000        -5.000000
#
#                 Period Terminated  No. Maker Contracts  \
# Periods Active
# 1                       -0.211886             0.575908
# 2                        0.083333             0.837945
# 3                        0.579710             1.042373
# 4                        1.230769             1.355932
# 5                        1.285714             1.413793
# ...
